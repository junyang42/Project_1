# %% [markdown]
# # Geocode Chicago Red Light Camera locations
# * geocode locations from the Propublica data set (https://www.propublica.org/datastore/dataset/chicago-parking-ticket-data)

# %% [markdown]
# ### Set up dependencies

# %%
# Import dependencies and key
import requests
import json
import pandas as pd

# Google developer API key
from config import gkey

# address file to read (generated from 'ChicagoTickets.ipynb')
csv_file = "Chicago_Count_by_Location.csv"

# %% [markdown]
# ### Read Addresses

# %%
# read the file created in ChicagoTickets.ipynb
df = pd.read_csv(csv_file)
df.head()
# Out:
#               address  Total First Ticket Date Last Ticket Date  Days  \
# 0         1 E 63RD ST  12038          3/3/2014        4/27/2018  1517
# 1     1 E 75TH STREET  15159          3/1/2014        4/27/2018  1519
# 2     1 E 79TH STREET  38135          3/1/2014        4/27/2018  1519
# 3     1 N ASHLAND AVE   7229          3/1/2014        4/27/2018  1519
# 4  1 N HALSTED STREET   5696          3/1/2014        4/27/2018  1519
#
#    Daily Avg
# 0   7.935399
# 1   9.979592
# 2  25.105332
# 3   4.759052
# 4   3.749835

# %% [markdown]
# ### Geocode and return lat/longitude

# %%
# base_url
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

# params
params = {"key": gkey}

for index, row in df.iterrows():
    # display message
    print(f"Geocoding {row['address']}")
    
    # add address to params
    params['address'] = f"{row['address']}, Chicago IL"
    
    # make request
    r = requests.get(base_url, params=params).json()
    
    # convert data to data frame
    try:
        # grab lat/long from 'geometry'
        df.loc[index, "Lat"] = r["results"][0]["geometry"]["location"]["lat"]
        df.loc[index, "Lng"] = r["results"][0]["geometry"]["location"]["lng"]
        
        # grab zip code from 'address_comonents'
        for i in r["results"][0]['address_components']:
            if i['types'][0] == "postal_code":
                df.loc[index, 'zipcode'] = i['short_name']
                break
    except:
        print(f"Error geocoding {row['address']}")
# Out:
# Geocoding 1 E 63RD ST
# Geocoding 1 E 75TH STREET
# Geocoding 1 E 79TH STREET
# Geocoding 1 N ASHLAND AVE
# Geocoding 1 N HALSTED STREET
# Geocoding 1 N HAMLIN AVENUE
# Geocoding 1 S CENTRAL AVENUE
# Geocoding 1 S HALSTED STREET
# Geocoding 1 S WESTERN AVE
# Geocoding 100 E JACKSON BLVD
# Geocoding 100 E ONTARIO ST
# Geocoding 100 N CICERO AVENUE
# Geocoding 100 W CHICAGO AVENUE
# Geocoding 1000 W FOSTER AVE
# Geocoding 1000 W HOLLYWOOD AVE
# Geocoding 10300 S HALSTED STREE
# Geocoding 10318 S INDIANAPOLIS
# Geocoding 1110 S PULASKI RD
# Geocoding 11100 S HALSTED ST
# Geocoding 11100 S VINCENNES AVE
# Geocoding 1111 N HUMBOLDT
# Geocoding 11144 S VINCENNES
# Geocoding 11153 S VINCENNES
# Geocoding 1117 S PULASKI RD
# Geocoding 1142 W IRVING PARK
# Geocoding 115 N OGDEN
# Geocoding 11500 S HALSTED STREE
# Geocoding 11900 S HALSTED
# Geocoding 1200 N ASHLAND AVENUE
# Geocoding 1200 N HALSTED
# Geocoding 1200 N PULASKI ROAD
# Geocoding 1200 S CANAL STREET
# Geocoding 1200 S KOSTNER
# Geocoding 1200 S PULASKI ROAD
# Geocoding 1200 W DEVON AVE
# Geocoding 1200 W FOSTER AVE
# Geocoding 1226 N WESTERN AVE
# Geocoding 1229 N WESTERN AVE
# Geocoding 1300 W IRVING PARK ROAD
# Geocoding 1315 W GARFIELD BLVD
# Geocoding 1334 W GARFIELD BLVD
# Geocoding 14 W CHICAGO AVE
# Geocoding 140 N ASHLAND
# Geocoding 140 W KINZIE
# Geocoding 141 N ASHLAND
# Geocoding 1440 W CERMAK RD
# Geocoding 150 N SACRAMENTO BOUL
# Geocoding 1507 W 83rd ST
# Geocoding 1600 E 79TH ST
# Geocoding 1600 E 83RD STREET
# Geocoding 1600 E 95TH STREET
# Geocoding 1600 N HALSTED STREET
# Geocoding 1600 N HOMAN AVENUE
# Geocoding 1600 N KOSTNER
# Geocoding 1600 N PULASKI AVENUE
# Geocoding 1600 N WESTERN AVE
# Geocoding 1600 W 63RD STREET
# Geocoding 1600 W 71ST
# Geocoding 1600 W 87TH ST
# Geocoding 1600 W 95TH STREET
# Geocoding 1600 W CORTLAND ST
# Geocoding 1600 W DIVERSEY PARKWA
# Geocoding 1600 W DIVISION STREET
# Geocoding 1600 W GARFIELD BLVD
# Geocoding 1600 W IRVING PARK ROA
# Geocoding 1600 W LAWRENCE AVENUE
# Geocoding 1600 W MADISON
# Geocoding 1635 N ASHLAND AVE
# Geocoding 1638 N ASHLAND AVE
# Geocoding 1754 N PULASKI RD
# Geocoding 18 W SUPERIOR ST
# Geocoding 19 W CHICAGO AVE
# Geocoding 1900 N ASHLAND AVE
# Geocoding 1901 E 75TH ST
# Geocoding 200 N UPPER WACKER DR
# Geocoding 200 W GARFIELD BLVD
# Geocoding 2000 E 79TH STREET
# Geocoding 2000 E 95TH ST
# Geocoding 2000 N CICERO AVENUE
# Geocoding 2000 N KEDZIE AVENUE
# Geocoding 2000 N WESTERN AVENUE
# Geocoding 2000 W DIVERSEY PARKWAY
# Geocoding 2000 W DIVISION
# Geocoding 2000 W FULLERTON AVE
# Geocoding 2080 W PERSHING
# Geocoding 2108 S WESTERN AVE
# Geocoding 2109 E 87TH ST
# Geocoding 2115 S WESTERN AVE
# Geocoding 215 E 63RD ST
# Geocoding 2200 S PULASKI
# Geocoding 2200 S WESTERN AVENUE
# Geocoding 2326 W CERMAK RD
# Geocoding 2329 W DIVISION ST
# Geocoding 2335 W CERMAK RD
# Geocoding 2348 S KOSTNER AVENUE
# Geocoding 2400 N ASHLAND AVENUE
# Geocoding 2400 N CENTRAL AVENUE
# Geocoding 2400 N CICERO AVE
# Geocoding 2400 N CLARK ST
# Geocoding 2400 N DAMEN AVE
# Geocoding 2400 N HALSTED STREET
# Geocoding 2400 N LARAMIE AVENUE
# Geocoding 2400 N PULASKI RD
# Geocoding 2400 N WESTERN AVENUE
# Geocoding 2400 W 51ST ST
# Geocoding 2400 W 55TH STREET
# Geocoding 2400 W 63RD ST
# Geocoding 2400 W 71ST STREET
# Geocoding 2400 W 79TH ST
# Geocoding 2400 W ADDISON
# Geocoding 2400 W CERMAK ROAD
# Geocoding 2400 W CHICAGO AVE
# Geocoding 2400 W DIVERSEY AVENUE
# Geocoding 2400 W FOSTER AVE
# Geocoding 2400 W LAWRENCE AVENUE
# Geocoding 2400 W MADISON
# Geocoding 2400 W MARQUETTE ROAD
# Geocoding 2400 W MONTROSE AVENUE
# Geocoding 2400 W NORTH AVE
# Geocoding 2400 W PERSHING ROAD
# Geocoding 2400 W PETERSON
# Geocoding 2400 W VAN BUREN STREET
# Geocoding 2416 S BLUE ISLAND AV
# Geocoding 2416 S DAMEN AVENUE
# Geocoding 2416 W 103RD ST
# Geocoding 2417 W 103RD ST
# Geocoding 2426 N DAMEN AVE
# Geocoding 2432 N ASHLAND
# Geocoding 2440 W 51ST ST
# Geocoding 2443 N ASHLAND
# Geocoding 2445 W 51ST ST
# Geocoding 2448 N CLYBOURN AVE
# Geocoding 2513 W 55TH
# Geocoding 2549 W ADDISON
# Geocoding 2550 W 79TH
# Geocoding 2600 S KEDZIE AVENUE
# Geocoding 2603 W 79TH
# Geocoding 2705 W IRVING PARK
# Geocoding 2712 W IRVING PARK
# Geocoding 2721 W MONTROSE
# Geocoding 2800 N ASHLAND AVENUE
# Geocoding 2800 N CALIFORNIA AVE
# Geocoding 2800 N CENTRAL AVENUE
# Geocoding 2800 N CICERO AVENUE
# Geocoding 2800 N DAMEN AVENUE
# Geocoding 2800 N KIMBALL AVENUE
# Geocoding 2800 N PULASKI ROAD
# Geocoding 2800 N WESTERN AVENUE
# Geocoding 2800 W 31ST
# Geocoding 2800 W DEVON AVENUE
# Geocoding 2800 W DIVERSEY
# Geocoding 2800 W IRVING PARK ROA
# Geocoding 2800 W PETERSON AVENUE
# Geocoding OGDEN and SACRAMENTO
# Geocoding 2912 W ROOSEVELT
# Geocoding 2917 W ROOSEVELT
# Geocoding 2928 S HALSTED
# Geocoding 30 W 87TH STREET
# Geocoding 300 N HAMLIN AVENUE
# Geocoding 300 S MICHIGAN AVE
# Geocoding 3000 W CHICAGO AVENUE
# Geocoding 3034 W FOSTER
# Geocoding 3047 W JACKSON BLVD
# Geocoding 3100 S ARCHER AVENUE
# Geocoding 3100 S ASHLAND AVENUE
# Geocoding 3100 S CALIFORNIA
# Geocoding 3100 S DR MARTIN L KING
# Geocoding 3100 S KEDZIE AVENUE
# Geocoding 3100 W AUGUSTA
# Geocoding 3111 N ASHLAND AVE
# Geocoding 3115 N NARRAGANSETT AVE
# Geocoding 3116 N NARRAGANSETT AVE
# Geocoding 3130 N ASHLAND AVE
# Geocoding 3137 W PETERSON
# Geocoding 319 E ILLINOIS ST
# Geocoding 3200 N CENTRAL AVENUE
# Geocoding 3200 N HARLEM AVE
# Geocoding 3200 N KEDZIE AVE
# Geocoding 3200 N KEDZIE AVENUE
# Geocoding 3200 N LAKESHORE DRIV
# Geocoding 3200 N PULASKI RD
# Geocoding 3200 S ARCHER AVE
# Geocoding 3200 W 31ST STREET
# Geocoding 3200 W 47TH ST
# Geocoding 3200 W 55TH STREET
# Geocoding 3200 W 63RD ST
# Geocoding 3200 W 71ST STREET
# Geocoding 3200 W 79TH ST
# Geocoding 3200 W ARMITAGE AVENUE
# Geocoding 3200 W BELMONT
# Geocoding 3200 W IRVING PARK ROAD
# Geocoding 3212 W 55TH ST
# Geocoding 3216 W ADDISON ST
# Geocoding 3217 W 55TH ST
# Geocoding 3230 N MILWAUKEE AVE
# Geocoding 324 E ILLINOIS ST
# Geocoding 324 S KEDZIE AVE
# Geocoding 340 W UPPER WACKER DR
# Geocoding 3400 W DIVERSEY AVENUE
# Geocoding 3400 W NORTH AVE
# Geocoding 341 W 76th ST
# Geocoding 3450 W 71ST
# Geocoding 346 W 76th ST
# Geocoding 3500 S WESTERN
# Geocoding 3521 N WESTERN
# Geocoding 3534 N WESTERN
# Geocoding 3535 E 95TH ST
# Geocoding 3542 E 95TH ST
# Geocoding 3600 N AUSTIN AVENUE
# Geocoding 3600 N CENTRAL AVENUE
# Geocoding 3600 N CICERO AVENUE
# Geocoding 3600 N ELSTON AVE
# Geocoding 3600 N HARLEM AVENUE
# Geocoding 3600 N WESTERN AVENUE
# Geocoding 3646 W MADISON
# Geocoding 3655 W JACKSON
# Geocoding 3700 W IRVING PARK ROA
# Geocoding 3800 W MADISON STREET
# Geocoding 3809 W BELMONT AVE
# Geocoding 3810 W BELMONT AVE
# Geocoding 3832 W 79TH
# Geocoding 3843 S WESTERN
# Geocoding 3843 W 111TH
# Geocoding 3851 W 79th
# Geocoding 3900 S WESTERN BLVD
# Geocoding 400 E 31ST STREET
# Geocoding 400 N CENTRAL AVENUE
# Geocoding 400 N LASALLE
# Geocoding 400 S WESTERN AVENUE
# Geocoding 400 W BELMONT AVE
# Geocoding 4000 N ASHLAND AVENUE
# Geocoding 4000 N AUSTIN AVENUE
# Geocoding 4000 N CENTRAL AVENUE
# Geocoding 4000 N CLARK STREET
# Geocoding 4000 N ELSTON AVENUE
# Geocoding 4000 N PULASKI ROAD
# Geocoding 4000 W 55TH ST
# Geocoding 4000 W 63RD ST
# Geocoding 4000 W 79TH STREET
# Geocoding 4000 W ARMITAGE AVENUE
# Geocoding 4000 W BELMONT AVE
# Geocoding 4000 W CERMAK
# Geocoding 4000 W CHICAGO AVENUE
# Geocoding 4000 W DIVERSEY AVENUE
# Geocoding 4000 W FOSTER AVE
# Geocoding 4000 W FULLERTON AVE
# Geocoding 4000 W IRVING PARK RD
# Geocoding 4000 W LAWRENCE AVENUE
# Geocoding 4000 W MONTROSE AVENUE
# Geocoding 4000 W NORTH AVENUE
# Geocoding 4000 W PETERSON AVENUE
# Geocoding 4000 W ROOSEVELT ROAD
# Geocoding 4040 W 55TH
# Geocoding 4040 W CHICAGO AVE
# Geocoding 4041 W CHICAGO AVE
# Geocoding 4042 W NORTH AVE
# Geocoding 4042 W ROOSEVELT RD
# Geocoding 4045 W 55TH
# Geocoding 4053 W NORTH AVE
# Geocoding 4123 N CENTRAL AVE
# Geocoding 4124 W FOSTER AVE
# Geocoding 4200 S CICERO AVENUE
# Geocoding 4400 N MILWAUKEE AVEN
# Geocoding 4400 N PULASKI ROAD
# Geocoding 4400 N WESTERN AVENUE
# Geocoding 4400 W GRAND AVE
# Geocoding 4400 W NORTH
# Geocoding 4400 W OGDEN AVENUE
# Geocoding 4400 W ROOSEVELT
# Geocoding 4429 N BROADWAY
# Geocoding 4432 N LINCOLN
# Geocoding 4433 N WESTERN
# Geocoding 4436 N WESTERN
# Geocoding 4440 W LAWRENCE AVENUE
# Geocoding 4446 N BROADWAY
# Geocoding 445 W 127TH
# Geocoding 449 N COLUMBUS DR
# Geocoding 450 N COLUMBUS DR
# Geocoding 4620 W BELMONT AVE
# Geocoding 4674 W PETERSON AVE
# Geocoding 4700 S ASHLAND AVENUE
# Geocoding 4700 S CICERO AVE
# Geocoding 4700 S KEDZIE AVE
# Geocoding 4700 S WESTERN AVENUE
# Geocoding 4700 W IRVING PARK ROA
# Geocoding 4707 W PETERSON AVE
# Geocoding 4800 N ASHLAND AVENUE
# Geocoding 4800 N CICERO AVE
# Geocoding 4800 N ELSTON AVENUE
# Geocoding 4800 N PULASKI ROAD
# Geocoding 4800 N WESTERN AVENUE
# Geocoding 4800 W 47TH ST
# Geocoding 4800 W ARMITAGE AVENUE
# Geocoding 4800 W CHICAGO AVENUE
# Geocoding 4800 W DIVERSEY AVENUE
# Geocoding 4800 W FULLERTON AVE
# Geocoding 4800 W HARRISON STREET
# Geocoding 4800 W NORTH AVENUE
# Geocoding 4800 W PETERSON AVENUE
# Geocoding 4831 W LAWRENCE AVE
# Geocoding 4843 W FULLERTON
# Geocoding 4909 N CICERO AVE
# Geocoding 4929 S PULASKI
# Geocoding 4932 W FOSTER AVENUE
# Geocoding 4965 S ARCHER
# Geocoding 500 N COLUMBUS DRIVE
# Geocoding 500 W ROOSEVELT ROAD
# Geocoding 5000 S ARCHER AVE
# Geocoding 5006 S WESTERN BLVD
# Geocoding 5025 S WESTERN AVE
# Geocoding 5030 S PULASKI
# Geocoding 506 S CENTRAL AVE
# Geocoding 5075 W MONTROSE AVENUE
# Geocoding 5100 S WESTERN BLVD
# Geocoding 5120 N PULASKI
# Geocoding 515 S CENTRAL AVE
# Geocoding 5200 N BROADWAY ST
# Geocoding 5200 N ELSTON AVENUE
# Geocoding 5200 N NAGLE
# Geocoding 5200 N NORTHWEST HWY
# Geocoding 5200 N PULASKI RD
# Geocoding 5200 N SHERIDAN ROAD
# Geocoding 5200 N WESTERN AVE
# Geocoding 5200 S CICERO AVE
# Geocoding 5200 W FULLERTON AVENUE
# Geocoding 5200 W IRVING PARK ROA
# Geocoding 5200 W MADISON STREET
# Geocoding 5232 N CENTRAL AVE
# Geocoding 5232 N MILWAUKEE AVE
# Geocoding 5330 S COTTAGE GROVE
# Geocoding 536 E MORGAN DR
# Geocoding 5400 S ARCHER AVE
# Geocoding 5420 S RACINE AVE
# Geocoding 5428 S PULASKI
# Geocoding 5432 W LAWRENCE
# Geocoding 5433 S PULASKI
# Geocoding 5440 W GRAND
# Geocoding 5446 W FULLERTON
# Geocoding 5454 W IRVING PARK
# Geocoding 5471 W HIGGINS
# Geocoding 5500 S ASHLAND AVENUE
# Geocoding 5500 S KEDZIE AVENUE
# Geocoding 5500 S PULASKI
# Geocoding 5500 S WENTWORTH AVEN
# Geocoding 5500 S WESTERN AVE
# Geocoding 5509 W FULLERTON
# Geocoding 5520 S WESTERN
# Geocoding 5529 S WESTERN
# Geocoding 5532 S KEDZIE AVE
# Geocoding 5600 W ADDISON STREET
# Geocoding 5600 W BELMONT AVENUE
# Geocoding 5600 W CHICAGO AVENUE
# Geocoding 5600 W DIVERSEY AVENUE
# Geocoding 5600 W FULLERTON AVENU
# Geocoding 5600 W IRVING PARK ROAD
# Geocoding 5600 W LAKE STREET
# Geocoding 5600 W MADISON STREET
# Geocoding 5616 W FOSTER AVE
# Geocoding 57 E 95TH
# Geocoding 5700 S CORNELL DRIVE
# Geocoding 5739 N NORTHWEST HWY
# Geocoding 5816 W JACKSON
# Geocoding 5885 N RIDGE AVE
# Geocoding 5930 N CLARK STREET
# Geocoding 600 S CICERO AVENUE
# Geocoding 6000 N CALIFORNIA AVE
# Geocoding 6000 N CICERO AVENUE
# Geocoding 6000 N PULASKI ROAD
# Geocoding 6000 N WESTERN AVE
# Geocoding 6000 W ADDISON STREET
# Geocoding 6000 W DIVERSEY AVENUE
# Geocoding 6000 W IRVING PARK ROAD
# Geocoding 6125 N CICERO AVE
# Geocoding 62 E 95TH
# Geocoding 6200 N KIMBALL AVENUE
# Geocoding 6200 N LINCOLN AVENUE
# Geocoding 6226 W IRVING PARK RD
# Geocoding 6247 W FULLERTON
# Geocoding 6250 W FULLERTON
# Geocoding 628 N MICHIGAN AVE
# Geocoding 629 S STATE
# Geocoding 630 S STATE
# Geocoding 6300 S ASHLAND AVE
# Geocoding 6300 S DAMEN AVENUE
# Geocoding 6300 S HALSTED STREET
# Geocoding 6300 S KEDZIE AVE
# Geocoding 6300 S PULASKI RD
# Geocoding 6300 S STATE ST
# Geocoding 6300 S WESTERN AVE
# Geocoding 6330 S MARTIN LUTHER KING
# Geocoding 6400 N CALIFORNIA AVE
# Geocoding 6400 N HARLEM AVE
# Geocoding 6400 N MILWAUKEE AVEN
# Geocoding 6400 N SHERIDAN ROAD
# Geocoding 6400 N WESTERN AVENUE
# Geocoding 6400 W ARCHER AVE
# Geocoding 6400 W DEVON AVENUE
# Geocoding 6400 W FOSTER
# Geocoding 6400 W FULLERTON AVENU
# Geocoding 6400 W IRVING PK
# Geocoding 6443 W BELMONT AVE
# Geocoding 6510 W BRYN MAWR AVE
# Geocoding 6514 W BELMONT AVE
# Geocoding 6523 N WESTERN
# Geocoding 6700 S CORNELL DRIVE
# Geocoding 6700 S STONY ISLAND A
# Geocoding 6700 S WESTERN AVENUE
# Geocoding 6800 N WESTERN AVENUE
# Geocoding 6800 W GRAND AVENUE
# Geocoding 6818 S KEDZIE
# Geocoding 6909 S KEDZIE
# Geocoding 7100 S ASHLAND
# Geocoding 7100 S COTTAGE GROVE
# Geocoding 7100 S KEDZIE AVENUE
# Geocoding 7100 S WESTERN AVENUE
# Geocoding 7200 N WESTERN AVENUE
# Geocoding 7200 W ADDISON
# Geocoding 7200 W BELMONT AVE
# Geocoding 732 N PULASKI RD
# Geocoding 7422 S JEFFERY
# Geocoding 7432 W TOUHY AVENUE
# Geocoding 7500 S STATE STREET
# Geocoding 7518 S VINCENNES
# Geocoding 7600 S STONY ISLAND A
# Geocoding 7738 S WESTERN
# Geocoding 7739 S WESTERN
# Geocoding 7826 S PULASKI
# Geocoding 7833 S PULASKI
# Geocoding 7900 S HALSTED STREET
# Geocoding 7900 S JEFFERY BOULEV
# Geocoding 7900 S KEDZIE AVE
# Geocoding 7900 S PULASKI ROAD
# Geocoding 7900 S SOUTH CHICAGO AVE
# Geocoding 7900 S STATE STREET
# Geocoding 7900 S STONEY ISLAND
# Geocoding 7900 S WESTERN AVE
# Geocoding 800 E 95TH STREET
# Geocoding 800 N CENTRAL AVENUE
# Geocoding 800 N CICERO AVENUE
# Geocoding 800 N PULASKI ROAD
# Geocoding 800 N SACRAMENTO AVEN
# Geocoding 800 N WESTERN AVE
# Geocoding 800 W 103RD STREET
# Geocoding 800 W 111TH ST
# Geocoding 800 W 115TH STREET
# Geocoding 800 W 119TH STREET
# Geocoding 800 W 79TH STREET
# Geocoding 800 W 99TH ST
# Geocoding 800 W DIVISION
# Geocoding 800 W FULLERTON AVENUE
# Geocoding 800 W NORTH AVENUE
# Geocoding 800 W ROOSEVELT ROAD
# Geocoding 8300 S HALSTED STREET
# Geocoding 8300 S STONY ISLAND A
# Geocoding 8318 S ASHLAND AVE
# Geocoding 8345 S ASHLAND AVE
# Geocoding 848 W 87TH STREET
# Geocoding 8700 S ASHLAND AVE
# Geocoding 8700 S LAFAYETTE AVEN
# Geocoding 8700 S VINCENNES
# Geocoding 9500 S ASHLAND AVENUE
# Geocoding 9500 S COTTAGE GROVE
# Geocoding 9500 S HALSTED STREET
# Geocoding 9500 S JEFFERY AVE
# Geocoding 9618 S EWING AVE
# Geocoding 9900 S HALSTED ST

# %%
# Save results to csv
df.to_csv("Chicago_Count_by_Location_LatLng.csv", index=False)
